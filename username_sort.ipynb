# %%
# import resource
import re
import json
import mysql.connector
import csv
import os
# csv_file = open('detuser.csv', 'w+')
# writer = csv.writer(csv_file)

inFile = open('detuser.csv','r', encoding="utf-8")

listLines = []

# count=0
# conn=mysql.connector.connect(user='root',password='Rahul',host='localhost',database='uk',port=3306)
# myc=conn.cursor(buffered=True)
# myc.execute("SELECT Username FROM details")
# result_set = myc.fetchall()

file_name = "done_inf.txt"
txt_file = open(file_name)

# result_set=f"{result_set}"
# result_set=result_set.replace("'","")


count=0
    
for row in inFile:
    
    listLines.append(row)
    count+=1
print(listLines)

# for line in txt_file :
# #     print(line)
#     if line in listLines:
# #         print("duplicate",line)
#         count+=1
        

#   m1="https://www.instagram.com/"+row #+"/"
#     m1=f"{m1}"
#     print(m1)
#     print(type(m1))
#     break
      
#       row=f"{row}"
#       row=row[2:-3:]
    
#       print(type(row))

#       print(row)
#       writer.writerow([row])
        
#       for word in result_set:
            
#             word=f"{word}"
#             word=word[2:-3:]
#             print(len(word))
#             if row == word:
#                 print(f"Duplicate = {row}")
#                 break
        
#       if result_set.find(row) = -1:
#         print(f"Duplicate = {row}")
        
#         continue
        
     
#     else:
#         l=row
#         m1="https://www.instagram.com/"+l
#         m1=f"{m1}"
#         outFile.write(line)
#         listLines.append(line)
#         print(m1)
#       count += 1

print(count)
txt_file.close()
# conn.close()
# Out:
# ['_____simun__\n', '____lets_fly\n', '___.bad___girl.___\n', '___.siprasini.___\n', '___.voguegirl.___\n', '___ammadu____\n', '___flyforfood___\n', '___navika\n', '___s_u_p_r_i_y_a___\n', '___strannikk___\n', '__.ani__.__\n', '__.bad___girl___\n', '__.diyaa._gupta\n', '__.mohammed.__46\n', '__.sahibpreet.__\n', '__akshay_patel\n', '__amrutha__chowdary__\n', '__angel_roshna__\n', '__arcadian\n', '__arman_18\n', '__back._.benchers__\n', '__be_loved__\n', '__brownihu_\n', '__chawla0004\n', '__dhritwinn__\n', '__food__vibes__\n', '__h.a.p.p.y__s.o.u.l\n', '__jatin__kumar__\n', '__jyotirmayee__\n', '__lasya.__\n', '__mayankchaudhary\n', '__megha_na__\n', '__miss_basu_\n', '__miss.__.das__\n', '__only_kewal_001\n', '__paras.kathpal__\n', '__patil_jay__\n', '__pradyasha__\n', '__professional__boy_\n', '__s__w__a__t__i__k__a\n', '__sahasra__honey__real____\n', '__sahasra_honey__real\n', '__sahasra_honey_real\n', '__saisiri_endlesslove__\n', '__shivani__naidu__\n', '__simran_satpathy.__\n', '__snehanjali__\n', '__sweetie_lovely__\n', '__that_foodie_girl__\n', '__ur_su_ha_ni__\n', '__vassundhara__\n', '_._beauty_beast_._\n', '_.anisha21_\n', '_.bongkudi._\n', '_.boyapati_devika._\n', '_.domi._nic_\n', '_.ekongkunal._\n', '_.foodie_woodie._\n', '_.ishikaa._\n', '_.ladydon.__\n', '_.madhu_.charm_\n', '_.nainikadances\n', '_.photo.phactory._\n', '_.r._a_s_h_m_.i._\n', '_.riyamalik\n', '_.shalu\n', '_.simu\n', '_.slimshady.__\n', '_.steevejoseph__\n', '_.steevejoseph._\n', '_.sunny_official\n', '_.varsha.dsouzaa._\n', '_.zahapanna_0x0x._\n', '_19_lii\n', '_1nstagram_01\n', '_28.11.99_\n', '_7_ramazanovna_7_\n', '_aahilkhan7\n', '_aanchalkhatri_\n', '_aashikabhatia_\n', '_abix_\n', '_abu_saalim_\n', '_adorefood_\n', '_aishwarya_asher\n', '_akantaaaaa___\n', '_akshai_akshi_\n', '_allaboutp_\n', '_allu_arjun_loverrs_\n', '_amansingh.08_\n', '_anannyakar_\n', '_angel_ankita_\n', '_angels_park\n', '_anshureddy\n', '_anudeepikaah___\n', '_arto__holic_\n', '_avi_saini_\n', '_b_u_d_d_u\n', '_babitayadav\n', '_badal_1212\n', '_bakelogy\n', '_bam_what\n', '_bhanu_1005\n', '_boho_gurl\n', '_bong_fo0die_\n', '_c_h_a_r_i_t_h_a__\n', '_candyfloss_____\n', '_chin.na_07\n', '_chinssssss\n', '_craving_it\n', '_damn.shoutout_\n', '_darkershade_\n', '_devika_bajaj_\n', '_devil_queen__._\n', '_dharvi_sharma\n', '_dhriti___._\n', '_diyakrishna_\n', '_dr.ankursingh\n', '_dream_catche_r_arya_official_\n', '_e.s.h.a.a.n_\n', '_endi3_\n', '_estheranil\n', '_evana_by_dil\n', '_fashion_sucker\n', '_focus_up_\n', '_food.check\n', '_foodandbae_\n', '_foodie._.moodie_\n', '_foodieduniya_\n', '_foodies_1195\n', '_foodies_station_\n', '_friendscollection29\n', '_gheeshakkar_\n', '_grannys_little_girl\n', '_great_grand_giveaway_\n', '_harmankhosa0714\n', '_harshitaaa\n', '_heena_lakwal\n', '_hell_walker\n', '_herbestmoves_\n', '_himani_zambre13\n', '_hungry.tummy_\n', '_iamishikaaa\n', '_iamkalash\n', '_ice.varya_\n', '_im_farmer_\n', '_imkhushboo_\n', '_indu_the_multicreative_\n', '_its_aryapraveen\n', '_its.singh_\n', '_itsankith\n', '_jagruti_mishra_official\n', '_jainpriyanka_\n', '_jasmin_honey_\n', '_jo.___jo__\n', '_justinspiring_\n', '_jyothsnajay_\n', '_jyotijha22\n', '_jyotu\n', '_k.m.l_d.e.e.p_\n', '_kalyani333_\n', '_kanishkamanwani_\n', '_kaur_talpreet\n', '_ketan_maan_13\n', '_kishu_shah_\n', '_kkaur12_\n', '_komalchauhan_\n', '_lizuuuu_\n', '_mamta_mohanta\n', '_manoj_4647\n', '_mansi__patra_\n', '_maple.glance_\n', '_mehaksethi_\n', '_melodyyy.__\n', '_misheeta\n', '_mittal_astha015_\n', '_mobile_photography______\n', '_mohitpuri_\n', '_molisha_96\n', '_moodie_fooodie\n', '_mr.ransy_2_3\n', '_mrs_akshai_\n', '_mukesh_gowda5\n', '_nandni_goyal\n', '_neeruttyy_\n', '_nidhi_chamoli\n', '_nidhi_tank_\n', '_niharikajain\n', '_nivedyanivyy_bliss\n', '_nivedyanivyy_offical\n', '_ornab\n', '_p_a_ll_a_v_i_\n', '_p_reran_a_\n', '_pallavipp_\n', '_pavithrashetty_\n', '_phoenixbae_\n', '_pinchofsalt._\n', '_play_boy_teja_.1\n', '_ponnu_vava\n', '_pranalimistry_\n', '_p ...
# 5562

# %%
inFile = open('done_inf.txt','r')

outFile = open('done_inf22.txt','w')

listLines = []

for line in inFile:

    if line in listLines:
        continue

    else:
        outFile.write(line)
        listLines.append(line)

outFile.close()

inFile.close()

# %%
txt_file = open('done_inf22.txt')

count = 0

for line in txt_file:
    count+=1
    
print(f'Number of Lines in the file is {count}')
txt_file.close()
# Out:
# Number of Lines in the file is 2687
