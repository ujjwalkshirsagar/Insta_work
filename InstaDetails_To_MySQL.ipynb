# %%
import requests
import re
import json
from bs4 import BeautifulSoup
import requests
import csv

csv_file = open('Garbage.csv', 'w+')
writer = csv.writer(csv_file)

import requests


cookies = {
    'mid': 'YROCfQALAAHAL0-Xxjc_bAAbFZOX',
    'ig_did': '60430A35-BA2F-4E48-8443-4B48038F429F',
    'ig_nrcb': '1',
    'rur': 'CLN\\\\05448449422522\\\\0541660732430:01f77d72eb8ada365c6a1fc573860f0dc3d84c62bfb4bfdc2c0b6a3b45f43250dad19888',
    'csrftoken': 'SRKNxbbbeg1olNl33zxwP7QE1or69bbZ',
    'ds_user_id': '48449422522',
    'sessionid': '48449422522%3AMBR0xBjunhgA91%3A5',
}

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:92.0) Gecko/20100101 Firefox/92.0',
    'Accept': '*/*',
    'Accept-Language': 'en-US,en;q=0.5',
    'Alt-Used': 'www.instagram.com',
    'Connection': 'keep-alive',
    'Referer': 'https://www.instagram.com/',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'TE': 'trailers',
}

params = (
    ('query_hash', 'ed2e3ff5ae8b96717476b62ef06ed8cc'),
    ('variables', '{"fetch_media_count":0,"fetch_suggested_count":30,"ignore_cache":true,"filter_followed_friends":true,"seen_ids":[],"include_reel":true}'),
)

response = requests.get('https://www.instagram.com/graphql/query/', headers=headers, params=params, cookies=cookies)


def extract_json_objects(text, decoder=json.JSONDecoder()):

    pos = 0
    while True:
        match = text.find('{', pos)
        if match == -1:
            break
        try:
            result, index = decoder.raw_decode(text[match:])
            yield result
            pos = match + index
        except ValueError:
            pos = match + 1
            
            
            
            
import mysql.connector
conn=mysql.connector.connect(user='root',password='Rahul',host='localhost',database='uk',port=3306)
sql="SELECT * FROM Usernames ORDER BY 'Sr_No' LIMIT 1367,32903;"

myc=conn.cursor(buffered=True)

myc.execute(sql)
for d in myc:
    try:
        a= list(d)
        url = a[1]
        print(url)
        html_content = requests.get(url,headers=headers, params=params,cookies=cookies).text
        soup = BeautifulSoup(html_content,'html.parser')
        data1=soup.find_all("script", type="text/javascript")[3]
        listToStr = ' '.join([str(elem) for elem in data1])
        data=listToStr[21:-1]
        y = json.loads(data)

    #     print(y["entry_data"]["ProfilePage"][0]["graphql"]['user'])
    #     print(data)
        
        l=y["entry_data"]["ProfilePage"][0]["graphql"]['user']["username"]
        print(f"Username - {l} ==============================================================> {type(l)}")
        l=f"{l}"
        
        m1="https://www.instagram.com/"+l+"/"
        print(f"Insta_Id - {m1} ==============================================================> {type(m1)}")
        m1=f"{m1}"
        
        m2=y["entry_data"]["ProfilePage"][0]["graphql"]['user']['id']
        print(f"Profile_Id - {m2} ==============================================================> {type(m2)}")
        
        m3=y["entry_data"]["ProfilePage"][0]["graphql"]['user']['biography']
        print(f"Bio - {m3} ==============================================================> {type(m3)}")
        m3=m3.replace('"','')
        m3=m3.replace("'","")
        m3=f"{m3}"
        print(m3)
        
        m4=y["entry_data"]["ProfilePage"][0]["graphql"]['user']['is_business_account']
        print(f"Is Business Account - {m4} ==============================================================> {type(m4)}")
        if m4==True:
            m4="True"
        else:
            m4="False"
        
        m5=y["entry_data"]["ProfilePage"][0]["graphql"]['user']['business_email']
        print(f"Email - {m5} ==============================================================> {type(m5)}")# if None then null
        if m5==None:
            m5="Null"
        
        
        m6=y["entry_data"]["ProfilePage"][0]["graphql"]['user']['edge_owner_to_timeline_media']['count']
        print(f"Posts - {m6} ==============================================================> {type(m6)}")
        
        m7=y["entry_data"]["ProfilePage"][0]["graphql"]['user']['edge_followed_by']['count']
        print(f"Followers - {m7} ==============================================================> {type(m7)}")
        
        m8=y["entry_data"]["ProfilePage"][0]["graphql"]['user']['edge_follow']['count']
        print(f"Following - {m8} ==============================================================> {type(m8)}")
        
        m9=y["entry_data"]["ProfilePage"][0]["graphql"]['user']['business_category_name']
        print(f"Business_category_name - {m9} ==============================================================> {type(m9)}") # if None then null
        if m9==None:
            m9="Null"
        
        m10=y["entry_data"]["ProfilePage"][0]["graphql"]['user']['category_name']
        print(f"Category_name - {m10} ==============================================================> {type(m10)}")
        m10=f"{m10}"
        
        if (m7 and m8)!=0:
            c="{0:.2f}".format(m7/m8)
        else:
            c="Null"
        print(f"Follower/following ratio - {c} ==============================================================> {type(c)}")
        
        conn1=mysql.connector.connect(user='root',password='Rahul',host='localhost',database='uk',port=3306)
        myc1=conn1.cursor(buffered=True)
        sql1=f"INSERT INTO details1(Username,Insta_Id,Profile_Id,Bio,Is_Business_Account,Email,Posts,Followers,Following,Business_Category_Name,Category_Name,FF_Ratio) VALUES ('{l}', '{m1}','{m2}','{m3}','{m4}','{m5}',{m6},{m7},{m8},'{m9}','{m10}','{c}');"
        myc1.execute(sql1)
        conn1.commit()
        
        
        
    except Exception as e:
        print(e)
        conn3=mysql.connector.connect(user='root',password='Rahul',host='localhost',database='uk',port=3306)
        myc3=conn3.cursor(buffered=True)
        sql3=f"INSERT INTO scrapid(name) VALUES('{url}')"
        myc3.execute(sql3)
        conn3.commit()
        
        continue

csv_file.close()
conn.close()
# Out:
# https://www.instagram.com/ritabhari_chakraborty/
# Username - ritabhari_chakraborty ==============================================================> <class 'str'>
# Insta_Id - https://www.instagram.com/ritabhari_chakraborty/ ==============================================================> <class 'str'>
# Profile_Id - 370286607 ==============================================================> <class 'str'>
# Bio - Deadpool x Doris Day = Me!
# Actor,Producer,Writer,Singer,Miniaturist
# @loveandminiatures @ucla grad,mother of 74 special children.
# Latest single SAWAN👇🏻 ==============================================================> <class 'str'>
# Deadpool x Doris Day = Me!
# Actor,Producer,Writer,Singer,Miniaturist
# @loveandminiatures @ucla grad,mother of 74 special children.
# Latest single SAWAN👇🏻
# Is Business Account - False ==============================================================> <class 'bool'>
# Email - None ==============================================================> <class 'NoneType'>
# Posts - 6960 ==============================================================> <class 'int'>
# Followers - 2562464 ==============================================================> <class 'int'>
# Following - 845 ==============================================================> <class 'int'>
# Business_category_name - None ==============================================================> <class 'NoneType'>
# Category_name - Actor ==============================================================> <class 'str'>
# Follower/following ratio - 3032.50 ==============================================================> <class 'str'>
# https://www.instagram.com/rupamislam/
# Username - rupamislam ==============================================================> <class 'str'>
# Insta_Id - https://www.instagram.com/rupamislam/ ==============================================================> <class 'str'>
# Profile_Id - 196782651 ==============================================================> <class 'str'>
# Bio - #TheRupamIslamPodcast Season 2- New episode is here! Click the link below. 👇🏽 ==============================================================> <class 'str'>
# #TheRupamIslamPodcast Season 2- New episode is here! Click the link below. 👇🏽
# Is Business Account - False ==============================================================> <class 'bool'>
# Email - None ==============================================================> <class 'NoneType'>
# Posts - 1193 ==============================================================> <class 'int'>
# Followers - 199315 ==============================================================> <class 'int'>
# Following - 27 ==============================================================> <class 'int'>
# Business_category_name - None ==============================================================> <class 'NoneType'>
# Category_name - Musician/Band ==============================================================> <class 'str'>
# Follower/following ratio - 7382.04 ==============================================================> <class 'str'>
# https://www.instagram.com/souravganguly/
# Username - souravganguly ==============================================================> <class 'str'>
# Insta_Id - https://www.instagram.com/souravganguly/ ==============================================================> <class 'str'>
# Profile_Id - 15856709847 ==============================================================> <class 'str'>
# Bio - Watch me Live with Classplus ==============================================================> <class 'str'>
# Watch me Live with Classplus
# Is Business Account - True ==============================================================> <class 'bool'>
# Email - None ==============================================================> <class 'NoneType'>
# Posts - 315 ==============================================================> <class 'int'>
# Followers - 2386488 ==============================================================> <class 'int'>
# Following - 83 ==============================================================> <class 'int'>
# Business_category_name - Creators & Celebrities ==============================================================> <class 'str'>
# Category_name - Personal Blog ==============================================================> <class 'str'>
# Follower/following ratio - 28752.87 ==============================================================> <class 'str'>
# https://www.instagram.com/i_sauravdas/
# Username - i_sauravdas ==============================================================> <class 'str'>
# Insta_Id - https://www.instagram.com/i_sauravdas/ ==============================================================> <class 'str'>
# Profile_Id - 501032276 ==============================================================> <class 'str'>
# Bio - The World or Nothing ✊🏿 ==============================================================> <class 'str'>
# The World or Nothing ✊🏿
# Is Business Account - False ==============================================================> <class 'bool'>
# Email - None ==============================================================> <class 'NoneType'>
# Posts - 735 ==============================================================> <class 'int'>
# Followers - 212314 ==============================================================> <class 'int'>
# Following - 43 ==============================================================> <class 'int'>
# Business_category_name - None ==============================================================> <class 'NoneType'>
# Category_name - Actor ==============================================================> <class 'str'>
# Follower/following ratio - 4937.53 ==============================================================> <class 'str'>
# https://www.instagram.com/mirchilajvanti/
# Username - mirchilajvanti ==============================================================> <class 'str'>
# Insta_Id - https://www.instagram.com/mirchilajvanti/ ==============================================================> <class 'str'>
# Profile_Id - 10345259129 ==============================================================> <class 'str'>
# Bio - Brewing words and life over coffee and smiles .
# Afternoon show host for 98.3 Mirchi Kolkata / Siliguri .
# Evening show host for @mirchi_usa . ==============================================================> <class 'str'>
# Brewing words and life over coffee and smiles .
# Afternoon show host for 98.3 Mirchi Kolkata / Siliguri .
# Evening show host for @mirchi_usa .
# Is Business Account - True ==============================================================> <class 'bool'>
# Email - None ==============================================================> <class 'NoneType'>
# Posts - 685 ==============================================================> <class 'int'>
# Followers - 23587 ==============================================================> <class 'int'>
# Following - 1597 ==============================================================> <class 'int'>
# Business_category_name - Creators & Celebrities ==============================================================> <class 'str'>
# Category_name - Public Figure ==============================================================> <class 'str'>
# Follower/following ratio - 14.77 ==============================================================> <class 'str'>
# https://www.instagram.com/deckle_edge/
# Username - deckle_edge ==============================================================> <class 'str'>
# Insta_Id - https://www.instagram.com/deckle_edge/ ==============================================================> <class 'str'>
# Profile_Id - 203349260 ==============================================================> <class 'str'>
# Bio - ☸ Founder- @ig_calcutta
# 🏆 Winner - Canon Photo Marathon India
# 💡 Exhibit- India's 1st @instagram exhibition
# 🎤 TEDx Speaker
# 🏅 HIPA (HIPA.ae) Finalist ==============================================================> <class 'str'>
# ☸ Founder- @ig_calcutta
# 🏆 Winner - Canon Photo Marathon India
# 💡 Exhibit- Indias 1st @instagram exhibition
# 🎤 TEDx Speaker
# 🏅 HIPA (HIPA.ae) Finalist
# Is Business Account - False ==============================================================> <class 'bool'>
# Email - None ==============================================================> <class 'NoneType'>
# Posts - 1153 ==============================================================> <class 'int'>
# Followers - 60554 ==============================================================> <class 'int'>
# Following - 181 ==============================================================> <class 'int'>
# Business_category_name - None ==============================================================> <class 'NoneType'>
# Category_name - Photographer ==============================================================> <class 'str'>
# Follower/following ratio - 334.55 ==============================================================> <class 'str'>
# https://www.instagram.com/ridhima.ghosh/
# Username - ridhima.ghosh ==============================================================> <class 'str'>
# Insta_Id - https://www.instagram.com/ridhima.ghosh/ ==============================================================> <class 'str'>
# Profile_Id - 50704849 ==============================================================> <class 'str'>
# Bio - Actor ==============================================================> <class 'str'>
# Actor
# Is Business Account - False ==============================================================> <class 'bool'>
# Email - None ==============================================================> <class 'NoneType'>
# Posts - 422 ==============================================================> <class 'int'>
# Followers - 360005 ==============================================================> <class 'int'>
# Following - 101 ==============================================================> <class 'int'>
# Business_category_name - None ==============================================================> <class 'NoneType'>
# Category_name - Actor ==============================================================> <class 'str'>
# Follower/following ratio - 3564.41 ==============================================================> <class 'str'>
# https://www.instagram.com/raimasen/
# Username - raimasen ==============================================================> <class 'str'>
# Insta_Id - https://www.instagram.com/raimasen/ ==============================================================> <class 'str'>
# Profile_Id - 377795485 ==============================================================> <class 'str'>
# Bio - Be yourself 🌟 ==============================================================> <class 'str'>
# Be yourself 🌟
# Is Business Account - False ==============================================================> <class 'bool'>
# Email - None ==============================================================> <class 'NoneType'>
# Posts - 407 ==============================================================> <class 'int'>
# Followers - 1357271 ==============================================================> <class 'int'>
# Following - 135 ==============================================================> <class 'int'>
# Business_category_name - None ==============================================================> <class 'NoneType'>
# Category_name - Actor ==============================================================> <class 'str'>
# Follower/following ratio - 10053.86 ==============================================================> <class 'str'>
# https://www.instagram.com/paoli_dam/
# Username - paoli_dam ==============================================================> <class 'str'>
# Insta_Id - https://www.instagram.com/paoli_dam/ ==============================================================> <class 'str'>
# Profile_Id - 1399940141 ==============================================================> <class 'str'>
# Bio - Actor ==============================================================> <class 'str'>
# Actor
# Is Business Account - True ==============================================================> <class 'bool'>
# Email - None ==============================================================> <class 'NoneType'>
# Posts - 1435 ==============================================================> <class 'int'>
# Followers - 753949 ==============================================================> <class 'int'>
# Following - 175 ==============================================================> <class 'int'>
# Business_category_name - Creators & Celebrities ==============================================================> <class 'str'>
# Category_name - None ==============================================================> <class 'NoneType'>
# Follower/following ratio - 4308.28 ==============================================================> <class 'str'>
# https://www.instagram.com/parnomittra/
# Username - parnomittra ==============================================================> <class 'str'>
# Insta_Id - https://www.instagram.com/parnomittra/ ==============================================================> <class 'str'>
# Profile_Id - 550738545 ==============================================================> <class 'str'>
# Bio - Actor/Wildchild /wallflower/zombie lover/scorpion
# Managed by @sise.in ==============================================================> <class 'str'>
# Actor/Wildchild /wallflower/zombie lover/scorpion
# Managed by @sise.in
# Is Business Account - True ==============================================================> <class 'bool'>
# Email - None ==============================================================> <class 'NoneType'>
# Posts - 1711 ==============================================================> <class 'int'>
# Followers - 735103 ==============================================================> <class 'int'>
# Following - 683 ==============================================================> <class 'int'>
# Business_category_name - Creators & Celebrities ==============================================================> <class 'str'>
# Category_name - Artist ==============================================================> <class 'str'>
# Follower/following ratio - 1076.29 ==============================================================> <class 'str'>
# https://www.instagram.com/monami_ghosh/
# Username - monami_ghosh ==============================================================> <class 'str'>
# Insta_Id - https://www.instagram.com/monami_ghosh/ ==============================================================> <class 'str'>
# Profile_Id - 1602592758 ==============================================================> <class 'str'>
# Bio - BRAND COLLAB CALL Enakshi +91 6290779540
# arindam@svf.in
# Behind the scenes DDJ👇 ==============================================================> <class 'str'>
# BRAND COLLAB CALL Enakshi +91 6290779540
# arindam@svf.in
# Behind the scenes DDJ👇
# Is Business Account - False ==============================================================> <class 'bool'>
# Email - None ==============================================================> <class 'NoneType'>
# Posts - 3184 ==============================================================> <class 'int'>
# Followers - 1469645 ==============================================================> <class 'int'>
# Following - 772 ==============================================================> <class 'int'>
# Business_category_name - None ==============================================================> <class 'NoneType'>
# Category_name - Actor ==============================================================> <class 'str'>
# Follower/following ratio - 1903.69 ==============================================================> <class 'str'>
# https://www.instagram.com/priyankasarkarz/
# Username - priyankasarkarz ==============================================================> <class 'str'>
# Insta_Id - https://www.instagram.com/priyankasarkarz/ ==============================================================> <class 'str'>
# Profile_Id - 1420247633 ==============================================================> <class 'str'>
# Bio -  ==============================================================> <class 'str'>
#
# Is Business Account - True ==============================================================> <class 'bool'>
# Email - None ==============================================================> <class 'NoneType'>
# Posts - 1397 ==============================================================> <class 'int'>
# Followers - 1803675 ==============================================================> <class 'int'>
# Following - 815 ==============================================================> <class 'int'>
# Business_category_name - Creators & Celebrities ==============================================================> <class 'str'>
# Category_name - Actor ==============================================================> <class 'str'>
# Follower/following ratio - 2213.10 ==============================================================> <class 'str'>
# https://www.instagram.com/madhumita_sarcar/
# Username - madhumita_sarcar ==============================================================> <class 'str'>
# Insta_Id - https://www.instagram.com/madhumita_sarcar/ ==============================================================> <class 'str'>
# Profile_Id - 2240622352 ==============================================================> <class 'str'>
# Bio - Vector in an infinite loop
# Managed by : @svfbrands
# Collaborations :6290779540 ==============================================================> <class 'str'>
# Vector in an infinite loop
# Managed by : @svfbrands
# Collaborations :6290779540
# Is Business Account - False ==============================================================> <class 'bool'>
# Email - None ==============================================================> <class 'NoneType'>
# Posts - 674 ==============================================================> <class 'int'>
# Followers - 1727178 ==============================================================> <class 'int'>
# Following - 475 ==============================================================> <class 'int'>
# Business_category_name - None ==============================================================> <class 'NoneType'>
# Category_name - Actor ==============================================================> <class 'str'>
# Follower/following ratio - 3636.16 ==============================================================> <class 'str'>
# https://www.instagram.com/iman_chakraborty/
# Username - iman_chakraborty ==============================================================> <class 'str'>
# Insta_Id - https://www.instagram.com/iman_chakraborty/ ==============================================================> <class 'str'>
# Profile_Id - 5554882341 ==============================================================> <class 'str'>
# Bio - Director of @imanchakrabortyproduction
# Follow us on
# FB:  www.facebook.com/ImanChakrabortyProduction/
# YT: www.youtube.com/c/imanchakrabortyproduction ==============================================================> <class 'str'>
# Director of @imanchakrabortyproduction
# Follow us on
# FB:  www.facebook.com/ImanChakrabortyProduction/
# YT: www.youtube.com/c/imanchakrabortyproduction
# Is Business Account - True ==============================================================> <class 'bool'>
# Email - None ==============================================================> <class 'NoneType'>
# Posts - 2035 ==============================================================> <class 'int'>
# Followers - 482774 ==============================================================> <class 'int'>
# Following - 525 ==============================================================> <class 'int'>
# Business_category_name - Creators & Celebrities ==============================================================> <class 'str'>
# Category_name - Musician ==============================================================> <class 'str'>
# Follower/following ratio - 919.57 ==============================================================> <class 'str'>
# https://www.instagram.com/rajchoco/
# Username - rajchoco ==============================================================> <class 'str'>
# Insta_Id - https://www.instagram.com/rajchoco/ ==============================================================> <class 'str'>
# Profile_Id - 3024608202 ==============================================================> <class 'str'>
# Bio -  ==============================================================> <class 'str'>
#
# Is Business Account - True ==============================================================> <class 'bool'>
# Email - None ==============================================================> <class 'NoneType'>
# Posts - 882 ==============================================================> <class 'int'>
# Followers - 879187 ==============================================================> <class 'int'>
# Following - 244 ==============================================================> <class 'int'>
# Business_category_name - Creators & Celebrities ==============================================================> <class 'str'>
# Category_name - None ==============================================================> <class 'NoneType'>
# Follower/following ratio - 3603.23 ==============================================================> <class 'str'>
# https://www.instagram.com/rukminimaitra/
# Username - rukminimaitra ==============================================================> <class 'str'>
# Insta_Id - https://www.instagram.com/rukminimaitra/ ==============================================================> <class 'str'>
# Profile_Id - 1641265960 ==============================================================> <class 'str'>
# Bio - ⭐💖 Of Heart & Highlight! 💖⭐ ==============================================================> <class 'str'>
# ⭐💖 Of Heart & Highlight! 💖⭐
# Is Business Account - False ==============================================================> <class 'bool'>
# Email - None ==============================================================> <class 'NoneType'>
# Posts - 1795 ==============================================================> <class 'int'>
# Followers - 1049135 ==============================================================> <class 'int'>
# Following - 452 ==============================================================> <class 'int'>
# Business_category_name - None ==============================================================> <class 'NoneType'>
# Category_name - Artist ==============================================================> <class 'str'>
# Follower/following ratio - 2321.10 ==============================================================> <class 'str'>
# https://www.instagram.com/baruog/
# Username - baruog ==============================================================> <class 'str'>
# Insta_Id - https://www.instagram.com/baruog/ ==============================================================> <class 'str'>
# Profile_Id - 37732948 ==============================================================> <class 'str'>
# Bio -  ==============================================================> <class 'str'>
#
# Is Business Account - False ==============================================================> <class 'bool'>
# Email - None ==============================================================> <class 'NoneType'>
# Posts - 1186 ==============================================================> <class 'int'>
# Followers - 241108 ==============================================================> <class 'int'>
# Following - 657 ==============================================================> <class 'int'>
# Business_category_name - None ==============================================================> <class 'NoneType'>
# Category_name - Actor ==============================================================> <class 'str'>
# Follower/following ratio - 366.98 ==============================================================> <class 'str'>
# https://www.instagram.com/aaluthefrenchfry/
# Username - aaluthefrenchfry ==============================================================> <class 'str'>
# Insta_Id - https://www.instagram.com/aaluthefrenchfry/ ==============================================================> <class 'str'>
# Profile_Id - 1537550668 ==============================================================> <class 'str'>
# Bio - 🍀Wanna B Your Favorite🍟
# 🥀100k+ YT & FB Family🤞
# 🍀Business : teamaaluthefrenchfry@gmail.com📩
# 🥀@aa_l_u🐈🐥
# 🍀KOLKATA🌸
# 🥀আর হ্যাঁ,আমি বাঙালি💌
# 🍀New Video Link👇 ==============================================================> <class 'str'>
# 🍀Wanna B Your Favorite🍟
# 🥀100k+ YT & FB Family🤞
# 🍀Business : teamaaluthefrenchfry@gmail.com📩
# 🥀@aa_l_u🐈🐥
# 🍀KOLKATA🌸
# 🥀আর হ্যাঁ,আমি বাঙালি💌
# 🍀New Video Link👇
# Is Business Account - False ==============================================================> <class 'bool'>
# Email - None ==============================================================> <class 'NoneType'>
# Posts - 691 ==============================================================> <class 'int'>
# Followers - 124600 ==============================================================> <class 'int'>
# Following - 69 ==============================================================> <class 'int'>
# Business_category_name - None ==============================================================> <class 'NoneType'>
# Category_name - Digital Creator ==============================================================> <class 'str'>
# Follower/following ratio - 1805.80 ==============================================================> <class 'str'>
# https://www.instagram.com/yourkoel/
# Username - yourkoel ==============================================================> <class 'str'>
# Insta_Id - https://www.instagram.com/yourkoel/ ==============================================================> <class 'str'>
# Profile_Id - 3270129704 ==============================================================> <class 'str'>
# Bio - An Artist & Humanitarian ==============================================================> <class 'str'>
# An Artist & Humanitarian
# Is Business Account - True ==============================================================> <class 'bool'>
# Email - None ==============================================================> <class 'NoneType'>
# Posts - 396 ==============================================================> <class 'int'>
# Followers - 1940389 ==============================================================> <class 'int'>
# Following - 75 ==============================================================> <class 'int'>
# Business_category_name - Creators & Celebrities ==============================================================> <class 'str'>
# Category_name - Artist ==============================================================> <class 'str'>
# Follower/following ratio - 25871.85 ==============================================================> <class 'str'>
# https://www.instagram.com/foodofdebjani/
# Username - foodofdebjani ==============================================================> <class 'str'>
# Insta_Id - https://www.instagram.com/foodofdebjani/ ==============================================================> <class 'str'>
# Profile_Id - 259196065 ==============================================================> <class 'str'>
# Bio - #workingmom #csrspecialist
# #foodwriter #recipecurator #foodstylist  #foodblogger  #homechef @ #debjanirrannaghar
# Covid food provider list ==============================================================> <class 'str'>
# #workingmom #csrspecialist
# #foodwriter #recipecurator #foodstylist  #foodblogger  #homechef @ #debjanirrannaghar
# Covid food provider list
# Is Business Account - False ==============================================================> <class 'bool'>
# Email - None ==============================================================> <class 'NoneType'>
# Posts - 1595 ==============================================================> <class 'int'>
# Followers - 38167 ==============================================================> <class 'int'>
# Following - 1416 ==============================================================> <class 'int'>
# Business_category_name - None ==============================================================> <class 'NoneType'>
# Category_name - Digital Creator ==============================================================> <class 'str'>
# Follower/following ratio - 26.95 ==============================================================> <class 'str'>
# https://www.instagram.com/atri.thestoryteller/
# Username - atri.thestoryteller ==============================================================> <class 'str'>
# Insta_Id - https://www.instagram.com/atri.thestoryteller/ ==============================================================> <class 'str'>
# Profile_Id - 1350645381 ==============================================================> <class 'str'>
# Bio - • Storyteller • Photographer • Writer • Doodler • Raconteur • Serial Procrastinator • Ceraunophile • Pluviophile • Content Creator @radiomirchi ==============================================================> <class 'str'>
# • Storyteller • Photographer • Writer • Doodler • Raconteur • Serial Procrastinator • Ceraunophile • Pluviophile • Content Creator @radiomirchi
# Is Business Account - False ==============================================================> <class 'bool'>
# Email - None ==============================================================> <class 'NoneType'>
# Posts - 692 ==============================================================> <class 'int'>
# Followers - 7393 ==============================================================> <class 'int'>
# Following - 852 ==============================================================> <class 'int'>
# Business_category_name - None ==============================================================> <class 'NoneType'>
# Category_name - Artist ==============================================================> <class 'str'>
# Follower/following ratio - 8.68 ==============================================================> <class 'str'>
# https://www.instagram.com/ssghosal/
# Username - ssghosal ==============================================================> <class 'str'>
# Insta_Id - https://www.instagram.com/ssghosal/ ==============================================================> <class 'str'>
# Profile_Id - 186517115 ==============================================================> <class 'str'>
# Bio - 🎯 Published Photographer | Educator
# 🏆 Govt. of India Awardee
# 📸 Official Mentor - Canon India
# 🎯 Detailed Bio 👇 ==============================================================> <class 'str'>
# 🎯 Published Photographer | Educator
# 🏆 Govt. of India Awardee
# 📸 Official Mentor - Canon India
# 🎯 Detailed Bio 👇
# Is Business Account - True ==============================================================> <class 'bool'>
# Email - None ==============================================================> <class 'NoneType'>
# Posts - 695 ==============================================================> <class 'int'>
# Followers - 8034 ==============================================================> <class 'int'>
# Following - 291 ==============================================================> <class 'int'>
# Business_category_name - Creators & Celebrities ==============================================================> <class 'str'>
# Category_name - Photographer ==============================================================> <class 'str'>
# Follower/following ratio - 27.61 ==============================================================> <class 'str'>
# https://www.instagram.com/surajitsaha1411/
# Username - surajitsaha1411 ==============================================================> <class 'str'>
# Insta_Id - https://www.instagram.com/surajitsaha1411/ ==============================================================> <class 'str'>
# Profile_Id - 27553980309 ==============================================================> <class 'str'>
# Bio - Food lover♥️😍
# Love 2 roam🔥🙏
# Food specilist🤗🤤
# Food blogger🎥
# Youtuber
# Follow my youtube channel-'Surajit saha'🙏♥️♥️🔥 ==============================================================> <class 'str'>
# Food lover♥️😍
# Love 2 roam🔥🙏
# Food specilist🤗🤤
# Food blogger🎥
# Youtuber
# Follow my youtube channel-Surajit saha🙏♥️♥️🔥
# Is Business Account - False ==============================================================> <class 'bool'>
# Email - None ==============================================================> <class 'NoneType'>
# Posts - 373 ==============================================================> <class 'int'>
# Followers - 2807 ==============================================================> <class 'int'>
# Following - 458 ==============================================================> <class 'int'>
# Business_category_name - None ==============================================================> <class 'NoneType'>
# Category_name - Video Creator ==============================================================> <class 'str'>
# Follower/following ratio - 6.13 ==============================================================> <class 'str'>
# https://www.instagram.com/debarshi.duttagupta/
# Username - debarshi.duttagupta ==============================================================> <class 'str'>
# Insta_Id - https://www.instagram.com/debarshi.duttagupta/ ==============================================================> <class 'str'>
# Profile_Id - 307737675 ==============================================================> <class 'str'>
# Bio - Love photographing extreme weather.. Official Fujifilm X Photographer ==============================================================> <class 'str'>
# Love photographing extreme weather.. Official Fujifilm X Photographer
# Is Business Account - True ==============================================================> <class 'bool'>
# Email - None ==============================================================> <class 'NoneType'>
# Posts - 1898 ==============================================================> <class 'int'>
# Followers - 3942 ==============================================================> <class 'int'>
# Following - 4795 ==============================================================> <class 'int'>
# Business_category_name - Creators & Celebrities ==============================================================> <class 'str'>
# Category_name - Personal Blog ==============================================================> <class 'str'>
# Follower/following ratio - 0.82 ==============================================================> <class 'str'>
# https://www.instagram.com/soumitra_10/
# Username - soumitra_10 ==============================================================> <class 'str'>
# Insta_Id - https://www.instagram.com/soumitra_10/ ==============================================================> <class 'str'>
# Profile_Id - 4370178133 ==============================================================> <class 'str'>
# Bio - Content Creator @bankuramemes
# BS MS IISER Mohali'19
# Watch "Ele But Gele Naa"👇 ==============================================================> <class 'str'>
# Content Creator @bankuramemes
# BS MS IISER Mohali19
# Watch Ele But Gele Naa👇
# Is Business Account - False ==============================================================> <class 'bool'>
# Email - None ==============================================================> <class 'NoneType'>
# Posts - 128 ==============================================================> <class 'int'>
# Followers - 6135 ==============================================================> <class 'int'>
# Following - 143 ==============================================================> <class 'int'>
# Business_category_name - None ==============================================================> <class 'NoneType'>
# Category_name - Artist ==============================================================> <class 'str'>
# Follower/following ratio - 42.90 ==============================================================> <class 'str'>
# https://www.instagram.com/tasteofcalcutta/
# Username - tasteofcalcutta ==============================================================> <class 'str'>
# Insta_Id - https://www.instagram.com/tasteofcalcutta/ ==============================================================> <class 'str'>
# Profile_Id - 4053611208 ==============================================================> <class 'str'>
# Bio - 🚕The Calcutta Curator🐟🚃🎷🎭
# 🤝 DM or email us for collabs
# #️⃣Use #tasteofcalcutta ==============================================================> <class 'str'>
# 🚕The Calcutta Curator🐟🚃🎷🎭
# 🤝 DM or email us for collabs
# #️⃣Use #tasteofcalcutta
# Is Business Account - False ==============================================================> <class 'bool'>
# Email - None ==============================================================> <class 'NoneType'>
# Posts - 1211 ==============================================================> <class 'int'>
# Followers - 37873 ==============================================================> <class 'int'>
# Following - 901 ==============================================================> <class 'int'>
# Business_category_name - None ==============================================================> <class 'NoneType'>
# Category_name - Digital Creator ==============================================================> <class 'str'>
# Follower/following ratio - 42.03 ==============================================================> <class 'str'>
# https://www.instagram.com/bankuramemes/
# Username - bankuramemes ==============================================================> <class 'str'>
# Insta_Id - https://www.instagram.com/bankuramemes/ ==============================================================> <class 'str'>
# Profile_Id - 3959299732 ==============================================================> <class 'str'>
# Bio - Watch Our Videos👇 ==============================================================> <class 'str'>
# Watch Our Videos👇
# Is Business Account - True ==============================================================> <class 'bool'>
# Email - None ==============================================================> <class 'NoneType'>
# Posts - 915 ==============================================================> <class 'int'>
# Followers - 19289 ==============================================================> <class 'int'>
# Following - 4 ==============================================================> <class 'int'>
# Business_category_name - Creators & Celebrities ==============================================================> <class 'str'>
# Category_name - Video Creator ==============================================================> <class 'str'>
# Follower/following ratio - 4822.25 ==============================================================> <class 'str'>
# https://www.instagram.com/soumya.ghosh25/
# Username - soumya.ghosh25 ==============================================================> <class 'str'>
# Insta_Id - https://www.instagram.com/soumya.ghosh25/ ==============================================================> <class 'str'>
# Profile_Id - 2246489435 ==============================================================> <class 'str'>
# Bio - Im a food and travel vlogger 🍔🚴‍♂️(YouTuber)
# Subscribe my youtube channel for unlimited food and travel experience ✌️Link is given below👇 ==============================================================> <class 'str'>
# Im a food and travel vlogger 🍔🚴‍♂️(YouTuber)
# Subscribe my youtube channel for unlimited food and travel experience ✌️Link is given below👇
# Is Business Account - True ==============================================================> <class 'bool'>
# Email - None ==============================================================> <class 'NoneType'>
# Posts - 366 ==============================================================> <class 'int'>
# Followers - 11660 ==============================================================> <class 'int'>
# Following - 291 ==============================================================> <class 'int'>
# Business_category_name - Creators & Celebrities ==============================================================> <class 'str'>
# Category_name - Video Creator ==============================================================> <class 'str'>
# Follower/following ratio - 40.07 ==============================================================> <class 'str'>
# https://www.instagram.com/tcp_thecalcuttaporkaddicts/
# Username - tcp_thecalcuttaporkaddicts ==============================================================> <class 'str'>
# Insta_Id - https://www.instagram.com/tcp_thecalcuttaporkaddicts/ ==============================================================> <class 'str'>
# Profile_Id - 7694194414 ==============================================================> <class 'str'>
# Bio - Community for Indian Pork Addicts
# Pork themed curated food events in CCU|BOM|BLR|DEL
# 🐷🐽🌭🥓
# Use #TCP & #TheCalcuttaPorkaddicts for feature
# Join below ==============================================================> <class 'str'>
# Community for Indian Pork Addicts
# Pork themed curated food events in CCU|BOM|BLR|DEL
# 🐷🐽🌭🥓
# Use #TCP & #TheCalcuttaPorkaddicts for feature
# Join below
# Is Business Account - True ==============================================================> <class 'bool'>
# Email - None ==============================================================> <class 'NoneType'>
# Posts - 4510 ==============================================================> <class 'int'>
# Followers - 3087 ==============================================================> <class 'int'>
# Following - 237 ==============================================================> <class 'int'>
# Business_category_name - Non-Profits & Religious Organizations ==============================================================> <class 'str'>
# Category_name - Community Organization ==============================================================> <class 'str'>
# Follower/following ratio - 13.03 ==============================================================> <class 'str'>
# https://www.instagram.com/camera_eatss_first/
# Username - camera_eatss_first ==============================================================> <class 'str'>
# Insta_Id - https://www.instagram.com/camera_eatss_first/ ==============================================================> <class 'str'>
# Profile_Id - 14313694556 ==============================================================> <class 'str'>
# Bio - 📍 Kolkata | Bhubaneshwar
# ¥oU oNLy l¡ve OnCe 😋
# L¡©K ȚhE b0wL 😜
# USE #cameatss1st to get featured
# Dm/Mail for promotions/collaborations/reviews ==============================================================> <class 'str'>
# 📍 Kolkata | Bhubaneshwar
# ¥oU oNLy l¡ve OnCe 😋
# L¡©K ȚhE b0wL 😜
# USE #cameatss1st to get featured
# Dm/Mail for promotions/collaborations/reviews
# Is Business Account - True ==============================================================> <class 'bool'>
# Email - None ==============================================================> <class 'NoneType'>
# Posts - 262 ==============================================================> <class 'int'>
# Followers - 23554 ==============================================================> <class 'int'>
# Following - 5474 ==============================================================> <class 'int'>
# Business_category_name - Food & Personal Goods ==============================================================> <class 'str'>
# Category_name - Food & Beverage ==============================================================> <class 'str'>
# Follower/following ratio - 4.30 ==============================================================> <class 'str'>
# https://www.instagram.com/kolkatafoodographer/
# Username - kolkatafoodographer ==============================================================> <class 'str'>
# Insta_Id - https://www.instagram.com/kolkatafoodographer/ ==============================================================> <class 'str'>
# Profile_Id - 7928765082 ==============================================================> <class 'str'>
# Bio - 🇮🇳 Indian Food Blogger and Photographer
# ⭐ Best Food Photographer at TFBA 2020
# 🍔 Zomato Connoisseur
# 🔎 Google Level 8
# 📲 Open to paid collaborations ==============================================================> <class 'str'>
# 🇮🇳 Indian Food Blogger and Photographer
# ⭐ Best Food Photographer at TFBA 2020
# 🍔 Zomato Connoisseur
# 🔎 Google Level 8
# 📲 Open to paid collaborations
# Is Business Account - False ==============================================================> <class 'bool'>
# Email - None ==============================================================> <class 'NoneType'>
# Posts - 917 ==============================================================> <class 'int'>
# Followers - 21042 ==============================================================> <class 'int'>
# Following - 5138 ==============================================================> <class 'int'>
# Business_category_name - None ==============================================================> <class 'NoneType'>
# Category_name - Blogger ==============================================================> <class 'str'>
# Follower/following ratio - 4.10 ==============================================================> <class 'str'>
# https://www.instagram.com/angika__chakraborty/
# Username - angika__chakraborty ==============================================================> <class 'str'>
# Insta_Id - https://www.instagram.com/angika__chakraborty/ ==============================================================> <class 'str'>
# Profile_Id - 41557859107 ==============================================================> <class 'str'>
# Bio - Be A Traveller Not A Tourist 🏝️🌐
# Unconditional love for food 🍛🍲🥗
# Passionate Blogger ❤️ ==============================================================> <class 'str'>
# Be A Traveller Not A Tourist 🏝️🌐
# Unconditional love for food 🍛🍲🥗
# Passionate Blogger ❤️
# Is Business Account - False ==============================================================> <class 'bool'>
# Email - None ==============================================================> <class 'NoneType'>
# Posts - 263 ==============================================================> <class 'int'>
# Followers - 30000 ==============================================================> <class 'int'>
# Following - 653 ==============================================================> <class 'int'>
# Business_category_name - None ==============================================================> <class 'NoneType'>
# Category_name - Blogger ==============================================================> <class 'str'>
# Follower/following ratio - 45.94 ==============================================================> <class 'str'>
# https://www.instagram.com/dharamshaladivine_life/
# Username - dharamshaladivine_life ==============================================================> <class 'str'>
# Insta_Id - https://www.instagram.com/dharamshaladivine_life/ ==============================================================> <class 'str'>
# Profile_Id - 4683074096 ==============================================================> <class 'str'>
# Bio - Dm us for adventure content sharing
# 💯 Credits and shoutouts
# to get featured on our page story...
# Bringing mountains to your screen
# ESTD : SINCE 2017 ==============================================================> <class 'str'>
# Dm us for adventure content sharing
# 💯 Credits and shoutouts
# to get featured on our page story...
# Bringing mountains to your screen
# ESTD : SINCE 2017
# Is Business Account - True ==============================================================> <class 'bool'>
# Email - None ==============================================================> <class 'NoneType'>
# Posts - 1038 ==============================================================> <class 'int'>
# Followers - 29739 ==============================================================> <class 'int'>
# Following - 531 ==============================================================> <class 'int'>
# Business_category_name - Creators & Celebrities ==============================================================> <class 'str'>
# Category_name - Digital Creator ==============================================================> <class 'str'>
# Follower/following ratio - 56.01 ==============================================================> <class 'str'>
# https://www.instagram.com/punti.kitchens/
# Username - punti.kitchens ==============================================================> <class 'str'>
# ...
# Use #jstfoodster to get featured😊
# Zomato Level 7 foodie
# Admin:@bansalanusha99
# A Delhi Mumbai Blogger
# Dm for collabs-invites-reviews
# Is Business Account - True ==============================================================> <class 'bool'>
# Email - None ==============================================================> <class 'NoneType'>
# Posts - 470 ==============================================================> <class 'int'>
# Followers - 19467 ==============================================================> <class 'int'>
# Following - 6650 ==============================================================> <class 'int'>
# Business_category_name - Food & Personal Goods ==============================================================> <class 'str'>
# Category_name - Food & Beverage ==============================================================> <class 'str'>
# Follower/following ratio - 2.93 ==============================================================> <class 'str'>
# https://www.instagram.com/desi_tastebuds/
# Username - desi_tastebuds ==============================================================> <class 'str'>
# Insta_Id - https://www.instagram.com/desi_tastebuds/ ==============================================================> <class 'str'>
# Profile_Id - 1428268709 ==============================================================> <class 'str'>
# Bio - Food Blogger
# love to cook | home-cooked food | food recipes on my post ==============================================================> <class 'str'>
# Food Blogger
# love to cook | home-cooked food | food recipes on my post
# Is Business Account - False ==============================================================> <class 'bool'>
# Email - None ==============================================================> <class 'NoneType'>
# Posts - 351 ==============================================================> <class 'int'>
# Followers - 20779 ==============================================================> <class 'int'>
# Following - 5330 ==============================================================> <class 'int'>
# Business_category_name - None ==============================================================> <class 'NoneType'>
# Category_name - Chef ==============================================================> <class 'str'>
# Follower/following ratio - 3.90 ==============================================================> <class 'str'>
# https://www.instagram.com/bhukkad_people/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/foods.fanatic/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/foodie_joypur/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/eatwithaditya/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/seetheunknownworld/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/mygharkakhana/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/my_kitchenn_diaries/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/tasty_cousinn/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/thestreetfoodaddict/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/foddiepeps/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/food_oo_graphy/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/foodieejodi/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/fictional_foodie/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/hyderabadifoodiesandco/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/scoop_n_slice/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/the_temptation_alley/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/qitchenqinara/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/fusionfoods__/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/foodiesfood_court/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/the_diehard_foodie/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/foodmood976/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/food_storieswithtrisha/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/ambrosia_bliss/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/love.for.food01/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/vandys__kitchen/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/food_mad101/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/universeofood/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/hungry_boti/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/sardaarjifoodie/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/chatora_panda/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/bangalifoodies/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/___flyforfood___/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/curly_tales2020/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/_foodie._.moodie_/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/foodie_crush18/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/foodgasm.india/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/the.gastronomical.voyage/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/non_veg_lovers/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/hashtagkolkatafood/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/thekolkatafoodfactory/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/non_vegfoodies/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/what_bengalis_eat/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/mrscookbook/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/bnrj_flavors/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/calcutta.stories/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/thecalcuttafoods/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/tales_of_shar/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/bangalipana/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/hyangla_bibi/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/baisakhis.instafood/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/fooddiariesss/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/indiafoodlife/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/bong_capture/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/therawtextures/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/thefoodiehat/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/spoonofflavours/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/golden_kolkata/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/baggygreensupriyo/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/kolkatalittlethings/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/mr._manasullas/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/tulika_indian_fooduae/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/thechowsquad/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/rosgolla/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/wonderkolkata/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/streetfoodie7/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/spicebasket/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/food_love_foodie/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/the.kolkata.vibes/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/the_tipsy_foodie/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/fatcat.studio.in/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/arokhai/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/capturing.imaginations/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/the_crazy_kolkata/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/kolkata_dorpon/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/miss.petuk/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/gouravfoodie/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/festozz/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/foodiekismatt/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/bongmumbaikar/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/foodie.bhasha/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/the__marinated/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/1_more_dream/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/jaipurkafoodiee/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/foodies_lover8/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/thedebonairmaven/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/the._.bigfoodie/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/indianfoodreview/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/delhifoodnest/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/bhookajaat/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/biryani_lovers__/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/tastebirdz/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/happiness_on_my_plate/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/foodiepanda__/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/the_foodielad/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/kolkata_city/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/thefoodysingh/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/thebengalifood/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/mv_kitchen_/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/rimleed/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/bong_chitrography/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/kolkata.camography/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/samitacuriouscook/
# Expecting value: line 1 column 1 (char 0)
# https://www.instagram.com/kolkata_chitrography/
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-1fbd280e1c57> in <module>
#      72         url = a[1]
#      73         print(url)
# ---> 74         html_content = requests.get(url,headers=headers, params=params,cookies=cookies).text
#      75         soup = BeautifulSoup(html_content,'html.parser')
#      76         data1=soup.find_all("script", type="text/javascript")[3]
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
CREATE TABLE details1(Sr_no INT AUTO_INCREMENT PRIMARY KEY,Username VARCHAR(100),Insta_Id VARCHAR(100),Profile_Id VARCHAR(100),Bio VARCHAR(300),Is_Business_Account VARCHAR(100),Email VARCHAR(100),Posts INT(255),Followers INT(255),Following INT(255),Business_Category_Name VARCHAR(100),Category_Name VARCHAR(100),FF_Ratio VARCHAR(100))

# %%
conn1.close()

# %%
m7=200
m8=422

c="{0:.2f}".format(m7/m8)
print(f"Follower/following ratio - {c} {type(c)}")

c=f"{c}"
print(f"2nd{c}")
# Out:
# Follower/following ratio - 0.47 <class 'str'>
# 2nd0.47

# %%
DEFAULT_VALUE="-"
result=0
if result is None:
    result = DEFAULT_VALUE
    print(result)

# %%
l="am_akankshasingh"

m1=f"https://www.instagram.com/{l}/"
print(m1)

# %%
import mysql.connector
conn=mysql.connector.connect(user='root',password='Rahul',host='localhost',database='new',port=3306)
myc=conn.cursor()

myc.execute("INSERT INTO json_col VALUES %s", json_value)
