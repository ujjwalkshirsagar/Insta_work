# %%
import requests
import re
import json
from bs4 import BeautifulSoup
import requests
import csv

csv_file = open('Garbage.csv', 'w+')
writer = csv.writer(csv_file)

import requests

cookies = {
    'mid': 'YROCfQALAAHAL0-Xxjc_bAAbFZOX',
    'ig_did': '60430A35-BA2F-4E48-8443-4B48038F429F',
    'ig_nrcb': '1',
    'datr': 'oFIeYXs2q-WkdaPWhCOmpXPP',
    'csrftoken': 'Cxb2YynAI2ju6xSq8gK1QvwvpXg0l78f',
    'rur': 'CLN\\\\05448449422522\\\\0541661098510:01f7f2168391107e292df8473f5b63a773ae620a5cff6f71a40f4e956423f32f7a734d9a',
    'ds_user_id': '48449422522',
    'sessionid': '48449422522%3ABtnNcRtuXJabVN%3A5',
}

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:92.0) Gecko/20100101 Firefox/92.0',
    'Accept': '*/*',
    'Accept-Language': 'en-US,en;q=0.5',
    'Alt-Used': 'www.instagram.com',
    'Connection': 'keep-alive',
    'Referer': 'https://www.instagram.com/',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'Cache-Control': 'max-age=0',
    'TE': 'trailers',
}

params = (
    ('query_hash', 'ed2e3ff5ae8b96717476b62ef06ed8cc'),
    ('variables', '{"fetch_media_count":0,"fetch_suggested_count":30,"ignore_cache":true,"filter_followed_friends":true,"seen_ids":[],"include_reel":true}'),
)


response = requests.get('https://www.instagram.com/graphql/query/', headers=headers, params=params, cookies=cookies)


def extract_json_objects(text, decoder=json.JSONDecoder()):

    pos = 0
    while True:
        match = text.find('{', pos)
        if match == -1:
            break
        try:
            result, index = decoder.raw_decode(text[match:])
            yield result
            pos = match + index
        except ValueError:
            pos = match + 1
            
            
            
            
import mysql.connector
conn=mysql.connector.connect(user='root',password='Rahul',host='localhost',database='uk',port=3306)
sql="SELECT * FROM Usernames ORDER BY 'Sr_No' LIMIT 3079,32903;"   #32903   #--3078

myc=conn.cursor(buffered=True)

myc.execute(sql)
for d in myc:
    try:
        a= list(d)
        url = a[1]
        print(url)
        html_content = requests.get(url,headers=headers, params=params,cookies=cookies).text
        soup = BeautifulSoup(html_content,'html.parser')
        data1=soup.find_all("script", type="text/javascript")[3]
        listToStr = ' '.join([str(elem) for elem in data1])
        data=listToStr[21:-1]
        y = json.loads(data)

    #     print(y["entry_data"]["ProfilePage"][0]["graphql"]['user'])
    #     print(data)
        
        l=y["entry_data"]["ProfilePage"][0]["graphql"]['user']["username"]
        print(f"Username - {l} ==============================================================> {type(l)}")
        l=f"{l}"
        
        m1="https://www.instagram.com/"+l+"/"
        print(f"Insta_Id - {m1} ==============================================================> {type(m1)}")
        m1=f"{m1}"
        
        m2=y["entry_data"]["ProfilePage"][0]["graphql"]['user']['id']
        print(f"Profile_Id - {m2} ==============================================================> {type(m2)}")
        
        m3=y["entry_data"]["ProfilePage"][0]["graphql"]['user']['biography']
        print(f"Bio - {m3} ==============================================================> {type(m3)}")
        m3=m3.replace('"','')
        m3=m3.replace("'","")
        m3=f"{m3}"
        print(m3)
        
        m4=y["entry_data"]["ProfilePage"][0]["graphql"]['user']['is_business_account']
        print(f"Is Business Account - {m4} ==============================================================> {type(m4)}")
        if m4==True:
            m4="True"
        else:
            m4="False"
        
        m5=y["entry_data"]["ProfilePage"][0]["graphql"]['user']['business_email']
        print(f"Email - {m5} ==============================================================> {type(m5)}")# if None then null
        if m5==None:
            m5="Null"
        
        
        m6=y["entry_data"]["ProfilePage"][0]["graphql"]['user']['edge_owner_to_timeline_media']['count']
        print(f"Posts - {m6} ==============================================================> {type(m6)}")
        
        m7=y["entry_data"]["ProfilePage"][0]["graphql"]['user']['edge_followed_by']['count']
        print(f"Followers - {m7} ==============================================================> {type(m7)}")
        
        m8=y["entry_data"]["ProfilePage"][0]["graphql"]['user']['edge_follow']['count']
        print(f"Following - {m8} ==============================================================> {type(m8)}")
        
        m9=y["entry_data"]["ProfilePage"][0]["graphql"]['user']['business_category_name']
        print(f"Business_category_name - {m9} ==============================================================> {type(m9)}") # if None then null
        if m9==None:
            m9="Null"
        
        m10=y["entry_data"]["ProfilePage"][0]["graphql"]['user']['category_name']
        print(f"Category_name - {m10} ==============================================================> {type(m10)}")
        m10=f"{m10}"
        
        if (m7 and m8)!=0:
            c="{0:.2f}".format(m7/m8)
        else:
            c="Null"
        print(f"Follower/following ratio - {c} ==============================================================> {type(c)}")
        
        conn1=mysql.connector.connect(user='root',password='Rahul',host='localhost',database='uk',port=3306)
        myc1=conn1.cursor(buffered=True)
        sql1=f"INSERT INTO details1(Username,Insta_Id,Profile_Id,Bio,Is_Business_Account,Email,Posts,Followers,Following,Business_Category_Name,Category_Name,FF_Ratio) VALUES ('{l}', '{m1}','{m2}','{m3}','{m4}','{m5}',{m6},{m7},{m8},'{m9}','{m10}','{c}');"
        myc1.execute(sql1)
        conn1.commit()
        
        
        
    except Exception as e:
        print(e)
        conn3=mysql.connector.connect(user='root',password='Rahul',host='localhost',database='uk',port=3306)
        myc3=conn3.cursor(buffered=True)
        sql3=f"INSERT INTO scrapid(name) VALUES('{url}')"
        myc3.execute(sql3)
        conn3.commit()
        
        continue
        
csv_file.close()
conn.close()
# Out:
# https://www.instagram.com/big_fan_of_naveen/
# Username - big_fan_of_naveen ==============================================================> <class 'str'>
# Insta_Id - https://www.instagram.com/big_fan_of_naveen/ ==============================================================> <class 'str'>
# Profile_Id - 38998832536 ==============================================================> <class 'str'>
# Bio - 💫tiktok star💫
# Fan girl of @its_me__navi❤🌎
# My Annayya: @__mr___decent_05❤
# 𝕯𝖎𝖊 𝖍𝖆𝖗𝖉 𝖋𝖆𝖓 𝖔𝖋 𝖓𝖆𝖛𝖊𝖊𝖓❤😘
# ✨𝓗𝓾𝓰𝓮 𝓯𝓪𝓷 𝓸𝓯 𝓱𝓲𝓼 𝓼𝓶𝓲𝓵𝓮...😊
# 🤩 𝕂𝕚𝕝𝕝𝕚𝕟𝕘 𝕖𝕩𝕡𝕣𝕖𝕤𝕤𝕚𝕠𝕟🤩 ==============================================================> <class 'str'>
# 💫tiktok star💫
# Fan girl of @its_me__navi❤🌎
# My Annayya: @__mr___decent_05❤
# 𝕯𝖎𝖊 𝖍𝖆𝖗𝖉 𝖋𝖆𝖓 𝖔𝖋 𝖓𝖆𝖛𝖊𝖊𝖓❤😘
# ✨𝓗𝓾𝓰𝓮 𝓯𝓪𝓷 𝓸𝓯 𝓱𝓲𝓼 𝓼𝓶𝓲𝓵𝓮...😊
# 🤩 𝕂𝕚𝕝𝕝𝕚𝕟𝕘 𝕖𝕩𝕡𝕣𝕖𝕤𝕤𝕚𝕠𝕟🤩
# Is Business Account - True ==============================================================> <class 'bool'>
# ...

# %%
import requests
import random 
from collections import OrderedDict
# This data was created by using the curl method explained above
headers_list = [
    
    #mYYYYYY
{
'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:92.0) Gecko/20100101 Firefox/92.0',
'Accept': '*/*',
'Accept-Language': 'en-US,en;q=0.5',
'Alt-Used': 'www.instagram.com',
'Connection': 'keep-alive',
'Referer': 'https://www.instagram.com/',
'Sec-Fetch-Dest': 'empty',
'Sec-Fetch-Mode': 'cors',
'Sec-Fetch-Site': 'same-origin',
'TE': 'trailers',
},
    

# Firefox 77 Windows
{
"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:77.0) Gecko/20100101 Firefox/77.0",
'Accept': '*/*',
'Accept-Language': 'en-US,en;q=0.5',
'Alt-Used': 'www.instagram.com',
'Connection': 'keep-alive',
'Referer': 'https://www.instagram.com/',
'Sec-Fetch-Dest': 'empty',
'Sec-Fetch-Mode': 'cors',
'Sec-Fetch-Site': 'same-origin',
'TE': 'trailers',
},
{
"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36",
'Accept': '*/*',
'Accept-Language': 'en-US,en;q=0.5',
'Alt-Used': 'www.instagram.com',
'Connection': 'keep-alive',
'Referer': 'https://www.instagram.com/',
'Sec-Fetch-Dest': 'empty',
'Sec-Fetch-Mode': 'cors',
'Sec-Fetch-Site': 'same-origin',
'TE': 'trailers',
},
{
"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:77.0) Gecko/20100101 Firefox/77.0",
'Accept': '*/*',
'Accept-Language': 'en-US,en;q=0.5',
'Alt-Used': 'www.instagram.com',
'Connection': 'keep-alive',
'Referer': 'https://www.instagram.com/',
'Sec-Fetch-Dest': 'empty',
'Sec-Fetch-Mode': 'cors',
'Sec-Fetch-Site': 'same-origin',
'TE': 'trailers',
},

# Chrome 83 Windows 
{
"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36",
'Accept': '*/*',
'Accept-Language': 'en-US,en;q=0.5',
'Alt-Used': 'www.instagram.com',
'Connection': 'keep-alive',
'Referer': 'https://www.instagram.com/',
'Sec-Fetch-Dest': 'empty',
'Sec-Fetch-Mode': 'cors',
'Sec-Fetch-Site': 'same-origin',
'TE': 'trailers',
}
]
# Create ordered dict from Headers above
ordered_headers_list = []
for headers in headers_list:
    h = OrderedDict()
    for header,value in headers.items():
        h[header]=value
        ordered_headers_list.append(h)
        
# for i in range(1,5):
# #Pick a random browser headers
#     headers = random.choice(headers_list)
# #Create a request session
#     r = requests.Session()
#     r.headers = headers
#     response = r.get(url)
#     print("Request #%d\nUser-Agent Sent:%s\n\nHeaders Recevied by HTTPBin:"%(i,headers['User-Agent']))
#     print(response.json())
#     print("-------------------")
    
#==========================================================================================================================


import requests
import re
import json
from bs4 import BeautifulSoup
import requests
import csv

csv_file = open('Garbage.csv', 'w+')
writer = csv.writer(csv_file)

import requests

cookies = {
    'mid': 'YROCfQALAAHAL0-Xxjc_bAAbFZOX',
    'ig_did': '60430A35-BA2F-4E48-8443-4B48038F429F',
    'ig_nrcb': '1',
    'rur': 'ODN\\\\05448668792797\\\\0541660908152:01f7cedd4fd6c10109a2d35b58af0656390f7bf5a7eb19734b1aa130103be92ce1435c40',
    'csrftoken': 'wESNwrwMYxkRR50WrNUIbu49BAwga0rf',
    'ds_user_id': '48668792797',
    'sessionid': '48668792797%3AmO9hW2N33pgzAZ%3A5',
}


params = (
    ('query_hash', 'ed2e3ff5ae8b96717476b62ef06ed8cc'),
    ('variables', '{"fetch_media_count":0,"fetch_suggested_count":30,"ignore_cache":true,"filter_followed_friends":true,"seen_ids":[],"include_reel":true}'),
)

#response = requests.get('https://www.instagram.com/graphql/query/', headers=headers, params=params, cookies=cookies)


def extract_json_objects(text, decoder=json.JSONDecoder()):

    pos = 0
    while True:
        match = text.find('{', pos)
        if match == -1:
            break
        try:
            result, index = decoder.raw_decode(text[match:])
            yield result
            pos = match + index
        except ValueError:
            pos = match + 1
            
            
            


import mysql.connector
conn=mysql.connector.connect(user='root',password='Rahul',host='localhost',database='uk',port=3306)
sql="SELECT * FROM Usernames ORDER BY 'Sr_No' LIMIT 2562,32903;"

myc=conn.cursor(buffered=True)

myc.execute(sql)
for d in myc:
    try:
        
        headers = random.choice(headers_list)
        a= list(d)
        url = a[1]
        print(url)
        html_content = requests.get(url,headers=headers, params=params,cookies=cookies).text
        soup = BeautifulSoup(html_content,'html.parser')
        data1=soup.find_all("script", type="text/javascript")[3]
        listToStr = ' '.join([str(elem) for elem in data1])
        data=listToStr[21:-1]
        y = json.loads(data)

    #     print(y["entry_data"]["ProfilePage"][0]["graphql"]['user'])
    #     print(data)
        
        l=y["entry_data"]["ProfilePage"][0]["graphql"]['user']["username"]
        print(f"Username - {l} ==============================================================> {type(l)}")
        l=f"{l}"
        
        m1="https://www.instagram.com/"+l+"/"
        print(f"Insta_Id - {m1} ==============================================================> {type(m1)}")
        m1=f"{m1}"
        
        m2=y["entry_data"]["ProfilePage"][0]["graphql"]['user']['id']
        print(f"Profile_Id - {m2} ==============================================================> {type(m2)}")
        
        m3=y["entry_data"]["ProfilePage"][0]["graphql"]['user']['biography']
        print(f"Bio - {m3} ==============================================================> {type(m3)}")
        m3=m3.replace('"','')
        m3=m3.replace("'","")
        m3=f"{m3}"
        print(m3)
        
        m4=y["entry_data"]["ProfilePage"][0]["graphql"]['user']['is_business_account']
        print(f"Is Business Account - {m4} ==============================================================> {type(m4)}")
        if m4==True:
            m4="True"
        else:
            m4="False"
        
        m5=y["entry_data"]["ProfilePage"][0]["graphql"]['user']['business_email']
        print(f"Email - {m5} ==============================================================> {type(m5)}")# if None then null
        if m5==None:
            m5="Null"
        
        
        m6=y["entry_data"]["ProfilePage"][0]["graphql"]['user']['edge_owner_to_timeline_media']['count']
        print(f"Posts - {m6} ==============================================================> {type(m6)}")
        
        m7=y["entry_data"]["ProfilePage"][0]["graphql"]['user']['edge_followed_by']['count']
        print(f"Followers - {m7} ==============================================================> {type(m7)}")
        
        m8=y["entry_data"]["ProfilePage"][0]["graphql"]['user']['edge_follow']['count']
        print(f"Following - {m8} ==============================================================> {type(m8)}")
        
        m9=y["entry_data"]["ProfilePage"][0]["graphql"]['user']['business_category_name']
        print(f"Business_category_name - {m9} ==============================================================> {type(m9)}") # if None then null
        if m9==None:
            m9="Null"
        
        m10=y["entry_data"]["ProfilePage"][0]["graphql"]['user']['category_name']
        print(f"Category_name - {m10} ==============================================================> {type(m10)}")
        m10=f"{m10}"
        
        if (m7 and m8)!=0:
            c="{0:.2f}".format(m7/m8)
        else:
            c="Null"
        print(f"Follower/following ratio - {c} ==============================================================> {type(c)}")
        
        conn1=mysql.connector.connect(user='root',password='Rahul',host='localhost',database='uk',port=3306)
        myc1=conn1.cursor(buffered=True)
        sql1=f"INSERT INTO details1(Username,Insta_Id,Profile_Id,Bio,Is_Business_Account,Email,Posts,Followers,Following,Business_Category_Name,Category_Name,FF_Ratio) VALUES ('{l}', '{m1}','{m2}','{m3}','{m4}','{m5}',{m6},{m7},{m8},'{m9}','{m10}','{c}');"
        myc1.execute(sql1)
        conn1.commit()
        
        
        
    except Exception as e:
        print(e)
        conn3=mysql.connector.connect(user='root',password='Rahul',host='localhost',database='uk',port=3306)
        myc3=conn3.cursor(buffered=True)
        sql3=f"INSERT INTO scrapid(name) VALUES('{url}')"
        myc3.execute(sql3)
        conn3.commit()
        continue
       
        

csv_file.close()
conn.close()
# Out:
# https://www.instagram.com/thefoodnovels/
# Username - thefoodnovels ==============================================================> <class 'str'>
# Insta_Id - https://www.instagram.com/thefoodnovels/ ==============================================================> <class 'str'>
# Profile_Id - 15966523957 ==============================================================> <class 'str'>
# Bio - Food Blogger
# Hogging and Blogging 😋
# Dm for Promotions and Collaborations
# Handled by - @sanyaa_agrawal
# 📍- Ahmedabad ==============================================================> <class 'str'>
# Food Blogger
# Hogging and Blogging 😋
# Dm for Promotions and Collaborations
# Handled by - @sanyaa_agrawal
# 📍- Ahmedabad
# Is Business Account - False ==============================================================> <class 'bool'>
# Email - None ==============================================================> <class 'NoneType'>
# ...

# %%
headers = random.choice(headers_list)
print(headers)
# Out:
# {'Connection': 'keep-alive', 'DNT': '1', 'Upgrade-Insecure-Requests': '1', 'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36', 'Accept': '*/*', 'Sec-Fetch-Dest': 'empty', 'Sec-Fetch-Mode': 'cors', 'Sec-Fetch-Site': 'same-origin', 'Referer': 'https://www.instagram.com/', 'Accept-Encoding': 'gzip, deflate, br', 'Accept-Language': 'en-US,en;q=0.5'}

# %%
CREATE TABLE details1(Sr_no INT AUTO_INCREMENT PRIMARY KEY,Username VARCHAR(100),Insta_Id VARCHAR(100),Profile_Id VARCHAR(100),Bio VARCHAR(300),Is_Business_Account VARCHAR(100),Email VARCHAR(100),Posts INT(255),Followers INT(255),Following INT(255),Business_Category_Name VARCHAR(100),Category_Name VARCHAR(100),FF_Ratio VARCHAR(100))
# Out:
#   File "<ipython-input-15-4a3a4939441c>", line 1
#     CREATE TABLE details1(Sr_no INT AUTO_INCREMENT PRIMARY KEY,Username VARCHAR(100),Insta_Id VARCHAR(100),Profile_Id VARCHAR(100),Bio VARCHAR(300),Is_Business_Account VARCHAR(100),Email VARCHAR(100),Posts INT(255),Followers INT(255),Following INT(255),Business_Category_Name VARCHAR(100),Category_Name VARCHAR(100),FF_Ratio VARCHAR(100))
#            ^
# SyntaxError: invalid syntax

# %%
conn1.close()

# %%
m7=200
m8=422

c="{0:.2f}".format(m7/m8)
print(f"Follower/following ratio - {c} {type(c)}")

c=f"{c}"
print(f"2nd{c}")
# Out:
# Follower/following ratio - 0.47 <class 'str'>
# 2nd0.47

# %%
DEFAULT_VALUE="-"
result=0
if result is None:
    result = DEFAULT_VALUE
    print(result)

# %%
l="am_akankshasingh"

m1=f"https://www.instagram.com/{l}/"
print(m1)

# %%
import mysql.connector
conn=mysql.connector.connect(user='root',password='Rahul',host='localhost',database='new',port=3306)
myc=conn.cursor()

myc.execute("INSERT INTO json_col VALUES %s", json_value)
