# %%
import requests
import re
import json
from bs4 import BeautifulSoup
import requests
import csv

csv_file = open('Sorted ID 1.csv', 'w+')
writer = csv.writer(csv_file)

import requests

cookies = {
    'mid': 'YROCfQALAAHAL0-Xxjc_bAAbFZOX',
    'ig_did': '60430A35-BA2F-4E48-8443-4B48038F429F',
    'ig_nrcb': '1',
    'csrftoken': '8U2HrrxvZKnfqW92KGznqBZ4IRVI7uus',
    'ds_user_id': '48668792797',
    'sessionid': '48668792797%3AUlAYOnwYvKF7T9%3A3',
    'rur': 'ODN\\\\05448668792797\\\\0541660662040:01f7a86530cd29f5458912c950092bbad0f95792e9fd52b9ce27c6b8e725a49d35bc1b4a',
}

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:92.0) Gecko/20100101 Firefox/92.0',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8',
    'Accept-Language': 'en-US,en;q=0.5',
    'Connection': 'keep-alive',
    'Upgrade-Insecure-Requests': '1',
    'Sec-Fetch-Dest': 'document',
    'Sec-Fetch-Mode': 'navigate',
    'Sec-Fetch-Site': 'none',
    'Sec-Fetch-User': '?1',
}


response = requests.get('https://www.instagram.com/graphql/query/', headers=headers, cookies=cookies)
def extract_json_objects(text, decoder=json.JSONDecoder()):

    pos = 0
    while True:
        match = text.find('{', pos)
        if match == -1:
            break
        try:
            result, index = decoder.raw_decode(text[match:])
            yield result
            pos = match + index
        except ValueError:
            pos = match + 1
            
            
            
            
import mysql.connector
conn=mysql.connector.connect(user='root',password='Rahul',host='localhost',database='uk',port=3306)
sql="SELECT * FROM Usernames ORDER BY 'Sr_No' LIMIT 5,32903;"
myc=conn.cursor(buffered=True)

myc.execute(sql)
for d in myc:
    try:
        a= list(d)
        url = a[1]
        print(url)
        html_content = requests.get(url,headers=headers, cookies=cookies).text
        soup = BeautifulSoup(html_content,'html.parser')
        data1=soup.find_all("script", type="text/javascript")[3]
        listToStr = ' '.join([str(elem) for elem in data1])
        data=listToStr[21:-1]
        y = json.loads(data)

    #     print(y["entry_data"]["ProfilePage"][0]["graphql"]['user'])
    #     print(data)
        
        l=y["entry_data"]["ProfilePage"][0]["graphql"]['user']["username"]
        print(f"Username - {l} ==============================================================> {type(l)}")
        l=f"{l}"
        
        m1="https://www.instagram.com/"+l+"/"
        print(f"Insta_Id - {m1} ==============================================================> {type(m1)}")
        m1=f"{m1}"
        
        m2=y["entry_data"]["ProfilePage"][0]["graphql"]['user']['id']
        print(f"Profile_Id - {m2} ==============================================================> {type(m2)}")
        
        m3=y["entry_data"]["ProfilePage"][0]["graphql"]['user']['biography']
        print(f"Bio - {m3} ==============================================================> {type(m3)}")
        m3=f"{m3}"
        
        m4=y["entry_data"]["ProfilePage"][0]["graphql"]['user']['is_business_account']
        print(f"Is Business Account - {m4} ==============================================================> {type(m4)}")
        if m4==True:
            m4="True"
        else:
            m4="False"
        
        m5=y["entry_data"]["ProfilePage"][0]["graphql"]['user']['business_email']
        print(f"Email - {m5} ==============================================================> {type(m5)}")# if None then null
        if m5==None:
            m5="Null"
        
        
        m6=y["entry_data"]["ProfilePage"][0]["graphql"]['user']['edge_owner_to_timeline_media']['count']
        print(f"Posts - {m6} ==============================================================> {type(m6)}")
        
        m7=y["entry_data"]["ProfilePage"][0]["graphql"]['user']['edge_followed_by']['count']
        print(f"Followers - {m7} ==============================================================> {type(m7)}")
        
        m8=y["entry_data"]["ProfilePage"][0]["graphql"]['user']['edge_follow']['count']
        print(f"Following - {m8} ==============================================================> {type(m8)}")
        
        m9=y["entry_data"]["ProfilePage"][0]["graphql"]['user']['business_category_name']
        print(f"Business_category_name - {m9} ==============================================================> {type(m9)}") # if None then null
        if m9==None:
            m9="Null"
        
        m10=y["entry_data"]["ProfilePage"][0]["graphql"]['user']['category_name']
        print(f"Category_name - {m10} ==============================================================> {type(m10)}")
        m10=f"{m10}"
        
        c="{0:.2f}".format(m7/m8)
        print(f"Follower/following ratio - {c} ==============================================================> {type(c)}")
        
        conn1=mysql.connector.connect(user='root',password='Rahul',host='localhost',database='uk',port=3306)
        myc1=conn1.cursor(buffered=True)
        sql1=f"INSERT INTO details1(Username,Insta_Id,Profile_Id,Bio,Is_Business_Account,Email,Posts,Followers,Following,Business_Category_Name,Category_Name,FF_Ratio) VALUES ('{l}', '{m1}','{m2}','{m3}','{m4}','{m5}',{m6},{m7},{m8},'{m9}','{m10}','{c}');"
        myc1.execute(sql1)
        conn1.commit()
        
        
        
    except Exception as e:
        print(e)
        break


conn.close()
# Out:
# https://www.instagram.com/chiccbychoice/
# Username - chiccbychoice ==============================================================> <class 'str'>
# Insta_Id - https://www.instagram.com/chiccbychoice/ ==============================================================> <class 'str'>
# Profile_Id - 46925817577 ==============================================================> <class 'str'>
# Bio - shop your aesthetics👒
# -Noida, India based 📍
# -cash on delivery available
# -free shipping on all orders ==============================================================> <class 'str'>
# Is Business Account - True ==============================================================> <class 'bool'>
# Email - None ==============================================================> <class 'NoneType'>
# Posts - 154 ==============================================================> <class 'int'>
# Followers - 3099 ==============================================================> <class 'int'>
# Following - 4090 ==============================================================> <class 'int'>
# Business_category_name - Personal Goods & General Merchandise Stores ==============================================================> <class 'str'>
# Category_name - Shopping & Retail ==============================================================> <class 'str'>
# Follower/following ratio - 0.76 ==============================================================> <class 'str'>
# https://www.instagram.com/mishvene_/
# Username - mishvene_ ==============================================================> <class 'str'>
# Insta_Id - https://www.instagram.com/mishvene_/ ==============================================================> <class 'str'>
# Profile_Id - 1374896379 ==============================================================> <class 'str'>
# Bio - Where love is thin faults are thick. •22• Sky is blue like me and you.
# Hey Siri, remove my makeup
# Thank you for vibing with me. Taadaaa ==============================================================> <class 'str'>
# Is Business Account - False ==============================================================> <class 'bool'>
# Email - None ==============================================================> <class 'NoneType'>
# Posts - 1059 ==============================================================> <class 'int'>
# Followers - 6719 ==============================================================> <class 'int'>
# Following - 1448 ==============================================================> <class 'int'>
# Business_category_name - None ==============================================================> <class 'NoneType'>
# Category_name - Personal Blog ==============================================================> <class 'str'>
# Follower/following ratio - 4.64 ==============================================================> <class 'str'>
# https://www.instagram.com/nishthaparwanda/
# Username - nishthaparwanda ==============================================================> <class 'str'>
# Insta_Id - https://www.instagram.com/nishthaparwanda/ ==============================================================> <class 'str'>
# Profile_Id - 5545167727 ==============================================================> <class 'str'>
# Bio - she/her
# To define is to limit. ==============================================================> <class 'str'>
# Is Business Account - False ==============================================================> <class 'bool'>
# Email - None ==============================================================> <class 'NoneType'>
# Posts - 2 ==============================================================> <class 'int'>
# Followers - 2471 ==============================================================> <class 'int'>
# Following - 666 ==============================================================> <class 'int'>
# Business_category_name - None ==============================================================> <class 'NoneType'>
# Category_name - None ==============================================================> <class 'NoneType'>
# Follower/following ratio - 3.71 ==============================================================> <class 'str'>
# https://www.instagram.com/rishika.narang/
# Username - rishika.narang ==============================================================> <class 'str'>
# Insta_Id - https://www.instagram.com/rishika.narang/ ==============================================================> <class 'str'>
# Profile_Id - 1409559136 ==============================================================> <class 'str'>
# Bio -  ==============================================================> <class 'str'>
# Is Business Account - False ==============================================================> <class 'bool'>
# Email - None ==============================================================> <class 'NoneType'>
# Posts - 96 ==============================================================> <class 'int'>
# Followers - 1857 ==============================================================> <class 'int'>
# Following - 973 ==============================================================> <class 'int'>
# Business_category_name - None ==============================================================> <class 'NoneType'>
# Category_name - None ==============================================================> <class 'NoneType'>
# Follower/following ratio - 1.91 ==============================================================> <class 'str'>
# https://www.instagram.com/anika.vid/
# Username - anika.vid ==============================================================> <class 'str'>
# Insta_Id - https://www.instagram.com/anika.vid/ ==============================================================> <class 'str'>
# Profile_Id - 4223265268 ==============================================================> <class 'str'>
# Bio - Where words fail, music speaks🌈✨ ==============================================================> <class 'str'>
# Is Business Account - False ==============================================================> <class 'bool'>
# Email - None ==============================================================> <class 'NoneType'>
# Posts - 198 ==============================================================> <class 'int'>
# Followers - 44305 ==============================================================> <class 'int'>
# Following - 340 ==============================================================> <class 'int'>
# Business_category_name - None ==============================================================> <class 'NoneType'>
# Category_name - Artist ==============================================================> <class 'str'>
# Follower/following ratio - 130.31 ==============================================================> <class 'str'>
# https://www.instagram.com/tanishkchaudhary._14/
# 'ProfilePage'

# %%
CREATE TABLE details1(Sr_no INT AUTO_INCREMENT PRIMARY KEY,Username VARCHAR(100),Insta_Id VARCHAR(100),Profile_Id VARCHAR(100),Bio VARCHAR(300),Is_Business_Account VARCHAR(100),Email VARCHAR(100),Posts INT(255),Followers INT(255),Following INT(255),Business_Category_Name VARCHAR(100),Category_Name VARCHAR(100),FF_Ratio VARCHAR(100))

# %%
conn1.close()

# %%
m7=200
m8=422

c="{0:.2f}".format(m7/m8)
print(f"Follower/following ratio - {c} {type(c)}")

c=f"{c}"
print(f"2nd{c}")
# Out:
# Follower/following ratio - 0.47 <class 'str'>
# 2nd0.47

# %%
DEFAULT_VALUE="-"
result=0
if result is None:
    result = DEFAULT_VALUE
    print(result)

# %%
l="am_akankshasingh"

m1=f"https://www.instagram.com/{l}/"
print(m1)

# %%
import mysql.connector
conn=mysql.connector.connect(user='root',password='Rahul',host='localhost',database='new',port=3306)
myc=conn.cursor()

myc.execute("INSERT INTO json_col VALUES %s", json_value)
