# %%
import requests
import random 
from collections import OrderedDict
# This data was created by using the curl method explained above
headers_list = [
    
    #mYYYYYY
{
'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:92.0) Gecko/20100101 Firefox/92.0',
'Accept': '*/*',
'Accept-Language': 'en-US,en;q=0.5',
'Alt-Used': 'www.instagram.com',
'Connection': 'keep-alive',
'Referer': 'https://www.instagram.com/',
'Sec-Fetch-Dest': 'empty',
'Sec-Fetch-Mode': 'cors',
'Sec-Fetch-Site': 'same-origin',
'TE': 'trailers',
},
    

# Firefox 77 Windows
{
"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:77.0) Gecko/20100101 Firefox/77.0",
'Accept': '*/*',
'Accept-Language': 'en-US,en;q=0.5',
'Alt-Used': 'www.instagram.com',
'Connection': 'keep-alive',
'Referer': 'https://www.instagram.com/',
'Sec-Fetch-Dest': 'empty',
'Sec-Fetch-Mode': 'cors',
'Sec-Fetch-Site': 'same-origin',
'TE': 'trailers',
},
{
"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36",
'Accept': '*/*',
'Accept-Language': 'en-US,en;q=0.5',
'Alt-Used': 'www.instagram.com',
'Connection': 'keep-alive',
'Referer': 'https://www.instagram.com/',
'Sec-Fetch-Dest': 'empty',
'Sec-Fetch-Mode': 'cors',
'Sec-Fetch-Site': 'same-origin',
'TE': 'trailers',
},
{
"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:77.0) Gecko/20100101 Firefox/77.0",
'Accept': '*/*',
'Accept-Language': 'en-US,en;q=0.5',
'Alt-Used': 'www.instagram.com',
'Connection': 'keep-alive',
'Referer': 'https://www.instagram.com/',
'Sec-Fetch-Dest': 'empty',
'Sec-Fetch-Mode': 'cors',
'Sec-Fetch-Site': 'same-origin',
'TE': 'trailers',
},

# Chrome 83 Windows 
{
"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36",
'Accept': '*/*',
'Accept-Language': 'en-US,en;q=0.5',
'Alt-Used': 'www.instagram.com',
'Connection': 'keep-alive',
'Referer': 'https://www.instagram.com/',
'Sec-Fetch-Dest': 'empty',
'Sec-Fetch-Mode': 'cors',
'Sec-Fetch-Site': 'same-origin',
'TE': 'trailers',
}
]
# Create ordered dict from Headers above
ordered_headers_list = []
for headers in headers_list:
    h = OrderedDict()
    for header,value in headers.items():
        h[header]=value
        ordered_headers_list.append(h)
        
# for i in range(1,5):
# #Pick a random browser headers
#     headers = random.choice(headers_list)
# #Create a request session
#     r = requests.Session()
#     r.headers = headers
#     response = r.get(url)
#     print("Request #%d\nUser-Agent Sent:%s\n\nHeaders Recevied by HTTPBin:"%(i,headers['User-Agent']))
#     print(response.json())
#     print("-------------------")
    
#==========================================================================================================================


import requests
import re
import json
from bs4 import BeautifulSoup
import requests
import csv

def extract_json_objects(text, decoder=json.JSONDecoder()):

    pos = 0
    while True:
        match = text.find('{', pos)
        if match == -1:
            break
        try:
            result, index = decoder.raw_decode(text[match:])
            yield result
            pos = match + index
        except ValueError:
            pos = match + 1
            
import mysql.connector

file_object = open('Qoruz_json.txt', 'a')

conn=mysql.connector.connect(user='root',password='Rahul',host='localhost',database='uk',port=3306)
sql="SELECT Insta_ID FROM Usernames ORDER BY 'Sr_No' LIMIT 3078,32903;"
myc=conn.cursor(buffered=True)
myc.execute(sql)

for d in myc:
    try:
        
       
        d=f"{d}"
#         print(d[28:-4:])
        url='https://data.qoruz.com/api/profiles.info?handle='+d[28:-4:]
        print(url)
        headers = random.choice(headers_list)
        html_content = requests.get(url,headers=headers).text
        soup = BeautifulSoup(html_content,'html.parser')
        listToStr = ' '.join([str(elem) for elem in soup])
        y = json.loads(listToStr)
        

#         print(type(y["ok"]))
    
        if y["ok"]==True:
            
            file_object.write(listToStr)
            file_object.write("\n")
            print("true")
            print("\n")
            
        else:


            print("false")
            print("\n")
            try:
                conn1=mysql.connector.connect(user='root',password='Rahul',host='localhost',database='uk',port=3306)
                myc1=conn1.cursor(buffered=True)
                sql1=f"INSERT INTO usernamesremained(Insta_ID) VALUES ('{d[28:-4:]}');"
                myc1.execute(sql1)
                conn1.commit()
            except:
                print("Duplicate")

        
        
    except Exception as e:
        print(e)
#         conn3=mysql.connector.connect(user='root',password='Rahul',host='localhost',database='uk',port=3306)
#         myc3=conn3.cursor(buffered=True)
#         sql3=f"INSERT INTO scrapid(name) VALUES('{url}')"
#         myc3.execute(sql3)
#         conn3.commit()
        continue      

# csv_file.close()
conn1.close()
file_object.close()

# %%
txt_file = open('Qoruz_json.txt')

count = 0

for line in txt_file:
    count+=1
    
print(f'Number of Lines in the file is {count}')
txt_file.close()
# Out:
# Number of Lines in the file is 7212

# %%
# import resource
import re
import json
import mysql.connector
import csv
import os
# csv_file = open('detuser.csv', 'w+')
# writer = csv.writer(csv_file)

inFile = open('detuser.csv','r', encoding="utf-8")

listLines = []

# count=0
# conn=mysql.connector.connect(user='root',password='Rahul',host='localhost',database='uk',port=3306)
# myc=conn.cursor(buffered=True)
# myc.execute("SELECT Username FROM details")
# result_set = myc.fetchall()

file_name = "done_inf.txt"
txt_file = open(file_name)

# result_set=f"{result_set}"
# result_set=result_set.replace("'","")


count=0
    
for row in inFile:
    
    listLines.append(row)
    
print(listLines)

for line in txt_file :
#     print(line)
    if line in listLines:
        print("duplicate",line)
        count+=1
        

#   m1="https://www.instagram.com/"+row #+"/"
#     m1=f"{m1}"
#     print(m1)
#     print(type(m1))
#     break
      
#       row=f"{row}"
#       row=row[2:-3:]
    
#       print(type(row))

#       print(row)
#       writer.writerow([row])
        
#       for word in result_set:
            
#             word=f"{word}"
#             word=word[2:-3:]
#             print(len(word))
#             if row == word:
#                 print(f"Duplicate = {row}")
#                 break
        
#       if result_set.find(row) = -1:
#         print(f"Duplicate = {row}")
        
#         continue
        
     
#     else:
#         l=row
#         m1="https://www.instagram.com/"+l
#         m1=f"{m1}"
#         outFile.write(line)
#         listLines.append(line)
#         print(m1)
#       count += 1

print(count)
txt_file.close()
csv_file.close()
conn.close()
